# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukyeong02/24-1-AI/blob/main/8_%EB%8B%A4%EC%A4%91%EB%B6%84%EB%A5%98%EB%94%A5%EB%9F%AC%EB%8B%9D_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

df = pd.read_csv('/content/drive/MyDrive/24-1학기 코딩 수업/인공지능/iris.csv', names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])

dataset = df.values
X = dataset[:,0:4].astype(float)
Y_obj = dataset[:,4]

e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = tf.keras.utils.to_categorical(Y)

model = Sequential()
model.add(Dense(16,  input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X, Y_encoded, epochs=50, batch_size=1)

prediction = model.predict(X)
for i in range(5):
  print("Prediction output: ", prediction[i])
  answer = np.argmax(prediction[i], axis=-1)
  print("Selected area: ", answer)
  print("Actual: ", Y_obj[i], ", Prediction: ", e.inverse_transform([answer])[0])
  print()
# Out:
# Epoch 1/50
# 150/150 [==============================] - 2s 5ms/step - loss: 1.0747 - accuracy: 0.6667
# Epoch 2/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8177 - accuracy: 0.6867
# Epoch 3/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7262 - accuracy: 0.7333
# Epoch 4/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6550 - accuracy: 0.7600
# Epoch 5/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5928 - accuracy: 0.8267
# Epoch 6/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5354 - accuracy: 0.8867
# Epoch 7/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4898 - accuracy: 0.9133
# Epoch 8/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4585 - accuracy: 0.9200
# Epoch 9/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4269 - accuracy: 0.9333
# Epoch 10/50
# ...
